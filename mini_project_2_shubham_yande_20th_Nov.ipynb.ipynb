# %% [markdown]
# # Import neccessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the dataset

# %%
df=pd.read_csv("Dry_Bean.csv")
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
df.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
df.shape
# Out:
# (13611, 17)

# %% [markdown]
# # logistic regression

# %%
x=df.drop('Class',axis=1)

# %%
y=df['Class']

# %%
## spliting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20)

# %%
x_train
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 8549   43684    776.510       286.797533       194.514908      1.474424
# 9283   47099    833.628       327.779351       185.274407      1.769156
# 937    38825    721.732       249.281355       198.615657      1.255094
# 10760  27725    612.615       228.847416       154.666512      1.479618
# 8475   43378    787.214       304.180475       182.437741      1.667311
# ...      ...        ...              ...              ...           ...
# 9620   49198    847.163       327.089464       193.051975      1.694308
# 7068   60147    957.495       384.500062       200.828982      1.914565
# 7391   68505   1028.344       420.666810       208.246857      2.020039
# 4367   70448   1027.708       396.922151       227.406928      1.745427
# 10714  27549    633.705       226.522626       156.185546      1.450343
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
y_train
# Out:
# 8549         SIRA
# 9283         SIRA
# 937         SEKER
# 10760    DERMASON
# 8475         SIRA
#            ...
# 9620         SIRA
# 7068        HOROZ
# 7391        HOROZ
# 4367         CALI
# 10714    DERMASON
# Name: Class, Length: 9527, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# E:\python.py\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array(['SEKER', 'BARBUNYA', 'DERMASON', ..., 'SEKER', 'BARBUNYA', 'CALI'],
#       dtype=object)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[238,   0, 120,   0,   2,   4,   2],
#        [  0, 164,   0,   0,   0,   0,   0],
#        [110,   1, 350,   0,  20,   0,   0],
#        [  0,   0,   0, 929,  28, 116,  55],
#        [ 64,   0,  19,   6, 327,   9, 106],
#        [  1,   0,   3,  41,   5, 385, 109],
#        [  5,   0,   2,  92, 158, 101, 512]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
lr_score=accuracy_score(y_pred,y_test)*100
lr_score
# Out:
# 71.13124387855045

# %%
from sklearn.metrics import classification_report

# %%
creport=classification_report(y_pred,y_test)
creport
# Out:
# '              precision    recall  f1-score   support\n\n    BARBUNYA       0.57      0.65      0.61       366\n      BOMBAY       0.99      1.00      1.00       164\n        CALI       0.71      0.73      0.72       481\n    DERMASON       0.87      0.82      0.85      1128\n       HOROZ       0.61      0.62      0.61       531\n       SEKER       0.63      0.71      0.66       544\n        SIRA       0.65      0.59      0.62       870\n\n    accuracy                           0.71      4084\n   macro avg       0.72      0.73      0.72      4084\nweighted avg       0.72      0.71      0.71      4084\n'

# %% [markdown]
# # support vector machine

# %%
df.head(3)
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER
# 2     0.908774      0.007244      0.003048      0.825871      0.999066  SEKER

# %%
x
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
y
# Out:
# 0           SEKER
# 1           SEKER
# 2           SEKER
# 3           SEKER
# 4           SEKER
#            ...
# 13606    DERMASON
# 13607    DERMASON
# 13608    DERMASON
# 13609    DERMASON
# 13610    DERMASON
# Name: Class, Length: 13611, dtype: object

# %%
from sklearn.svm import SVC

# %%
sv=SVC(kernel='linear')

# %%
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
ypred=sv.predict(x_test)

# %%
ypred
# Out:
# array(['SIRA', 'BARBUNYA', 'DERMASON', ..., 'SEKER', 'BARBUNYA', 'CALI'],
#       dtype=object)

# %%
sv.score=sv.score(x_test,y_test)*100
sv.score
# Out:
# 91.307541625857

# %% [markdown]
# # Knn

# %%
x_train
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 8549   43684    776.510       286.797533       194.514908      1.474424
# 9283   47099    833.628       327.779351       185.274407      1.769156
# 937    38825    721.732       249.281355       198.615657      1.255094
# 10760  27725    612.615       228.847416       154.666512      1.479618
# 8475   43378    787.214       304.180475       182.437741      1.667311
# ...      ...        ...              ...              ...           ...
# 9620   49198    847.163       327.089464       193.051975      1.694308
# 7068   60147    957.495       384.500062       200.828982      1.914565
# 7391   68505   1028.344       420.666810       208.246857      2.020039
# 4367   70448   1027.708       396.922151       227.406928      1.745427
# 10714  27549    633.705       226.522626       156.185546      1.450343
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
y_train
# Out:
# 8549         SIRA
# 9283         SIRA
# 937         SEKER
# 10760    DERMASON
# 8475         SIRA
#            ...
# 9620         SIRA
# 7068        HOROZ
# 7391        HOROZ
# 4367         CALI
# 10714    DERMASON
# Name: Class, Length: 9527, dtype: object

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier( n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)
# Out:
# E:\python.py\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.metrics import classification_report

# %%
report=classification_report(y_test,y_pred)
report
# Out:
# '              precision    recall  f1-score   support\n\n    BARBUNYA       0.51      0.50      0.51       418\n      BOMBAY       1.00      0.99      1.00       165\n        CALI       0.66      0.65      0.66       494\n    DERMASON       0.81      0.89      0.85      1068\n       HOROZ       0.66      0.64      0.65       540\n       SEKER       0.81      0.58      0.68       615\n        SIRA       0.63      0.71      0.67       784\n\n    accuracy                           0.71      4084\n   macro avg       0.73      0.71      0.71      4084\nweighted avg       0.71      0.71      0.71      4084\n'

# %%
print('classification',classification_report(y_test,y_pred))
# Out:
# classification               precision    recall  f1-score   support
#
#     BARBUNYA       0.51      0.50      0.51       418
#       BOMBAY       1.00      0.99      1.00       165
#         CALI       0.66      0.65      0.66       494
#     DERMASON       0.81      0.89      0.85      1068
#        HOROZ       0.66      0.64      0.65       540
#        SEKER       0.81      0.58      0.68       615
#         SIRA       0.63      0.71      0.67       784
#
#     accuracy                           0.71      4084
#    macro avg       0.73      0.71      0.71      4084
# weighted avg       0.71      0.71      0.71      4084

# %%
from sklearn.metrics import confusion_matrix

# %%
print('confusion_metrix',confusion_matrix(y_test,y_pred))
# Out:
# confusion_metrix [[209   0 147   0  51   0  11]
#  [  0 164   1   0   0   0   0]
#  [143   0 322   0  27   0   2]
#  [  0   0   0 953   2  49  64]
#  [ 49   0  18  14 347   0 112]
#  [  1   0   0 110  11 358 135]
#  [  7   0   0  99  87  37 554]]

# %%
knn.score = accuracy_score(y_test, y_pred)*100
knn.score
# Out:
# 71.18021547502448

# %% [markdown]
# # navie bayes

# %%
len(x_train)
# Out:
# 9527

# %%
len(x_test)
# Out:
# 4084

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb= GaussianNB()
nb
# Out:
# GaussianNB()

# %%
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb.predict(x_test)

# %%
y_pred
# Out:
# array(['SIRA', 'BARBUNYA', 'DERMASON', ..., 'SIRA', 'CALI', 'CALI'],
#       dtype='<U8')

# %%
x_test
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 9028   45833    794.578       295.200437       198.067382      1.490404
# 2666   69229   1028.211       374.702605       236.669232      1.583233
# 10477  26425    595.532       216.947305       155.375961      1.396273
# 11710  31455    660.540       255.068955       157.533490      1.619141
# 6108   50513    929.206       382.863923       169.209763      2.262659
# ...      ...        ...              ...              ...           ...
# 4769   75852   1071.325       416.212730       235.463969      1.767628
# 13582  41826    772.831       294.586813       181.312184      1.624749
# 1804   45862    778.266       274.232710       213.121370      1.286744
# 3065   77492   1134.539       428.923013       231.931769      1.849350
# 5417   92098   1199.087       464.877520       254.183211      1.828907
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
as4=accuracy_score(y_test,y_pred)*100
as4
# Out:
# 76.37120470127327

# %%
from sklearn.metrics import classification_report

# %%
print('classificationr',classification_report(ypred,y_test))
# Out:
# classificationr               precision    recall  f1-score   support
#
#     BARBUNYA       0.86      0.94      0.90       384
#       BOMBAY       0.99      1.00      1.00       164
#         CALI       0.95      0.90      0.92       522
#     DERMASON       0.91      0.92      0.91      1057
#        HOROZ       0.95      0.95      0.95       536
#        SEKER       0.93      0.94      0.94       612
#         SIRA       0.87      0.84      0.85       809
#
#     accuracy                           0.91      4084
#    macro avg       0.92      0.93      0.92      4084
# weighted avg       0.91      0.91      0.91      4084

# %% [markdown]
# # decision_tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()
dt
# Out:
# DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred=dt.predict(x_test)
ypred
# Out:
# array(['SIRA', 'BARBUNYA', 'DERMASON', ..., 'SEKER', 'CALI', 'CALI'],
#       dtype=object)

# %%
x_test
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 9028   45833    794.578       295.200437       198.067382      1.490404
# 2666   69229   1028.211       374.702605       236.669232      1.583233
# 10477  26425    595.532       216.947305       155.375961      1.396273
# 11710  31455    660.540       255.068955       157.533490      1.619141
# 6108   50513    929.206       382.863923       169.209763      2.262659
# ...      ...        ...              ...              ...           ...
# 4769   75852   1071.325       416.212730       235.463969      1.767628
# 13582  41826    772.831       294.586813       181.312184      1.624749
# 1804   45862    778.266       274.232710       213.121370      1.286744
# 3065   77492   1134.539       428.923013       231.931769      1.849350
# 5417   92098   1199.087       464.877520       254.183211      1.828907
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
print('acurracy_score',accuracy_score(ypred,y_test)*100)
# Out:
# acurracy_score 88.83447600391773

# %%
as5=accuracy_score(ypred,y_test)*100
as5
# Out:
# 88.83447600391773

# %%
from sklearn.metrics import classification_report

# %%
print('cr',classification_report(y_test,y_pred))
# Out:
# cr               precision    recall  f1-score   support
#
#     BARBUNYA       0.68      0.50      0.58       418
#       BOMBAY       1.00      1.00      1.00       165
#         CALI       0.69      0.79      0.74       494
#     DERMASON       0.87      0.84      0.85      1068
#        HOROZ       0.77      0.79      0.78       540
#        SEKER       0.70      0.69      0.70       615
#         SIRA       0.71      0.78      0.74       784
#
#     accuracy                           0.76      4084
#    macro avg       0.77      0.77      0.77      4084
# weighted avg       0.76      0.76      0.76      4084

# %% [markdown]
# # Performance Comparision

# %%
x=['logistic_regression','SVM','Knn','Decision_tree','navie bayes']
y=[71.13,91.30,71.18,88.83,76.37]
c=('b','r','g','y','k')
plt.xlabel("operation")
plt.ylabel("score")
plt.title("operation VS score")

plt.bar(x,y,color=c)
plt.grid()
plt.show()
